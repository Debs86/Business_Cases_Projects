# %% [markdown]
# # Business Case #5 - Retail - Demand Forecasting

# %% [markdown]
# ## Authors:
# #### Débora Santos (m20200748),Pedro Henrique Medeiros (m20200742), Rebeca Pinheiro (m20201096)
#
# #### Group D - D4B Consulting

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\vanes\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\vanes\anaconda3\lib\site-packages (from lightgbm) (0.24.1)
# Requirement already satisfied: numpy in c:\users\vanes\anaconda3\lib\site-packages (from lightgbm) (1.20.1)
# Requirement already satisfied: scipy in c:\users\vanes\anaconda3\lib\site-packages (from lightgbm) (1.6.2)
# Requirement already satisfied: wheel in c:\users\vanes\anaconda3\lib\site-packages (from lightgbm) (0.36.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\vanes\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vanes\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)

# %%
#IMPORT LIBRARIES
import sqlite3
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os.path import join
import seaborn as sns
from datetime import datetime
from itertools import product
from math import ceil
# %matplotlib inline 
from collections import Counter
import matplotlib.cm as cm


#Models
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, explained_variance_score, mean_absolute_error, mean_squared_error, median_absolute_error
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import PredefinedSplit
from sklearn.metrics import make_scorer
from sklearn.tree import DecisionTreeRegressor

# Use garbage collection to minimise memory usage
import gc

import warnings
warnings.filterwarnings("ignore")

# Seeting seaborn style
sns.set()

# %%
def downcast1(df, verbose=True):
    
    """
    Funciton to reduce the memory used of a particular dataframe by downcasting to a less memory-intensive data type.
    """
    
    start_mem = df.memory_usage().sum() / 1024**2
    
    for col in df.columns:
        dtype_name = df[col].dtype.name
        if dtype_name == 'object':
            pass
        elif dtype_name == 'bool':
            df[col] = df[col].astype('int8')
        elif dtype_name.startswith('int') or (df[col].round() == df[col]).all():
            df[col] = pd.to_numeric(df[col], downcast='integer')
        else:
            df[col] = pd.to_numeric(df[col], downcast='float')
    
    end_mem = df.memory_usage().sum() / 1024**2
    
    if verbose:
        print('{:.1f}% compressed'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
#import dataset in csv
df_forecast = pd.read_csv('df_demand_complete.csv')

# %%
df_forecast.head()
# Out:
#    Year_Week  Store_ID  Product_ID  Quantity  Product_ID_Quantity_mean  \
# 0     201728         1        1000         2                  1.828851
# 1     201728         1        1001         0                  0.056235
# 2     201728         1        1002         4                  1.303178
# 3     201728         1        1003         0                  2.026895
# 4     201728         1        1004         0                  2.009780
#
#    Product_ID_Store_ID_Quantity_mean  Store_ID_Quantity_mean  Quantity_lag1  \
# 0                                  2                2.163561              0
# 1                                  0                2.163561              0
# 2                                  4                2.163561              2
# 3                                  0                2.163561              0
# 4                                  0                2.163561              0
#
#    Quantity_lag2  Quantity_lag3  ...  Product_ID_Quantity_mean_lag3  \
# 0              0              0  ...                       1.687042
# 1              0              0  ...                       0.034230
# 2              5              4  ...                       1.293398
# 3              0              0  ...                       1.762836
# 4              2              2  ...                       1.684597
#
#    Product_ID_Store_ID_Quantity_mean_lag1  \
# 0                                       0
# 1                                       0
# 2                                       2
# 3                                       0
# 4                                       0
#
#    Product_ID_Store_ID_Quantity_mean_lag2  \
# 0                                       0
# 1                                       0
# 2                                       5
# 3                                       0
# 4                                       2
#
#    Product_ID_Store_ID_Quantity_mean_lag3  Store_ID_Quantity_mean_lag1  \
# 0                                       0                     1.985345
# 1                                       0                     1.985345
# 2                                       4                     1.985345
# 3                                       0                     1.985345
# 4                                       2                     1.985345
#
#    Store_ID_Quantity_mean_lag2  Store_ID_Quantity_mean_lag3  \
# 0                     1.992302                     1.791754
# 1                     1.992302                     1.791754
# 2                     1.992302                     1.791754
# 3                     1.992302                     1.791754
# 4                     1.992302                     1.791754
#
#    Quantity_lag3_mean  lag_grad_1  lag_grad_2
# 0            0.000000         0.0        0.00
# 1            0.000000         0.0        0.00
# 2            3.666667         0.4        1.25
# 3            0.000000         0.0        0.00
# 4            1.333333         0.0        1.00
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Split the data

# %%
#Create train, val and test data spliting by last 6 weeks to test set, more 6 weeks to validation set 
train = df_forecast[df_forecast['Year_Week']<201932]

# %%
val = df_forecast[df_forecast['Year_Week']>=201932]
val = val[val['Year_Week']<201938]

# %%
test = df_forecast[df_forecast['Year_Week']>=201938]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111647593 entries, 0 to 115659473
# Data columns (total 22 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   Year_Week                               int32
#  1   Store_ID                                int16
#  2   Product_ID                              int16
#  3   Quantity                                int8
#  4   Product_ID_Quantity_mean                float32
#  5   Product_ID_Store_ID_Quantity_mean       int16
#  6   Store_ID_Quantity_mean                  float32
#  7   Quantity_lag1                           int8
#  8   Quantity_lag2                           int8
#  9   Quantity_lag3                           int8
#  10  Product_ID_Quantity_mean_lag1           float32
#  11  Product_ID_Quantity_mean_lag2           float32
#  12  Product_ID_Quantity_mean_lag3           float32
#  13  Product_ID_Store_ID_Quantity_mean_lag1  int8
#  14  Product_ID_Store_ID_Quantity_mean_lag2  int8
#  15  Product_ID_Store_ID_Quantity_mean_lag3  int8
#  16  Store_ID_Quantity_mean_lag1             float32
#  17  Store_ID_Quantity_mean_lag2             float32
#  18  Store_ID_Quantity_mean_lag3             float32
#  19  Quantity_lag3_mean                      float32
#  20  lag_grad_1                              float32
#  21  lag_grad_2                              float32
# dtypes: float32(11), int16(3), int32(1), int8(7)
# memory usage: 7.2 GB

# %%
val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4011881 entries, 14602527 to 105285597
# Data columns (total 22 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   Year_Week                               int32
#  1   Store_ID                                int16
#  2   Product_ID                              int16
#  3   Quantity                                int8
#  4   Product_ID_Quantity_mean                float32
#  5   Product_ID_Store_ID_Quantity_mean       int16
#  6   Store_ID_Quantity_mean                  float32
#  7   Quantity_lag1                           int8
#  8   Quantity_lag2                           int8
#  9   Quantity_lag3                           int8
#  10  Product_ID_Quantity_mean_lag1           float32
#  11  Product_ID_Quantity_mean_lag2           float32
#  12  Product_ID_Quantity_mean_lag3           float32
#  13  Product_ID_Store_ID_Quantity_mean_lag1  int8
#  14  Product_ID_Store_ID_Quantity_mean_lag2  int8
#  15  Product_ID_Store_ID_Quantity_mean_lag3  int8
#  16  Store_ID_Quantity_mean_lag1             float32
#  17  Store_ID_Quantity_mean_lag2             float32
#  18  Store_ID_Quantity_mean_lag3             float32
#  19  Quantity_lag3_mean                      float32
#  20  lag_grad_1                              float32
#  21  lag_grad_2                              float32
# dtypes: float32(11), int16(3), int32(1), int8(7)
# memory usage: 264.0 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4702273 entries, 115659474 to 120361746
# Data columns (total 22 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   Year_Week                               int32
#  1   Store_ID                                int16
#  2   Product_ID                              int16
#  3   Quantity                                int8
#  4   Product_ID_Quantity_mean                float32
#  5   Product_ID_Store_ID_Quantity_mean       int16
#  6   Store_ID_Quantity_mean                  float32
#  7   Quantity_lag1                           int8
#  8   Quantity_lag2                           int8
#  9   Quantity_lag3                           int8
#  10  Product_ID_Quantity_mean_lag1           float32
#  11  Product_ID_Quantity_mean_lag2           float32
#  12  Product_ID_Quantity_mean_lag3           float32
#  13  Product_ID_Store_ID_Quantity_mean_lag1  int8
#  14  Product_ID_Store_ID_Quantity_mean_lag2  int8
#  15  Product_ID_Store_ID_Quantity_mean_lag3  int8
#  16  Store_ID_Quantity_mean_lag1             float32
#  17  Store_ID_Quantity_mean_lag2             float32
#  18  Store_ID_Quantity_mean_lag3             float32
#  19  Quantity_lag3_mean                      float32
#  20  lag_grad_1                              float32
#  21  lag_grad_2                              float32
# dtypes: float32(11), int16(3), int32(1), int8(7)
# memory usage: 309.4 MB

# %%
#Remove target variable and save it in separate
X_train = train.drop('Quantity', axis=1)
y_train = train['Quantity']
X_val = val.drop('Quantity', axis=1)
y_val = val['Quantity']

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111647593 entries, 0 to 115659473
# Data columns (total 21 columns):
#  #   Column                                  Dtype
# ---  ------                                  -----
#  0   Year_Week                               int32
#  1   Store_ID                                int16
#  2   Product_ID                              int16
#  3   Product_ID_Quantity_mean                float32
#  4   Product_ID_Store_ID_Quantity_mean       int16
#  5   Store_ID_Quantity_mean                  float32
#  6   Quantity_lag1                           int8
#  7   Quantity_lag2                           int8
#  8   Quantity_lag3                           int8
#  9   Product_ID_Quantity_mean_lag1           float32
#  10  Product_ID_Quantity_mean_lag2           float32
#  11  Product_ID_Quantity_mean_lag3           float32
#  12  Product_ID_Store_ID_Quantity_mean_lag1  int8
#  13  Product_ID_Store_ID_Quantity_mean_lag2  int8
#  14  Product_ID_Store_ID_Quantity_mean_lag3  int8
#  15  Store_ID_Quantity_mean_lag1             float32
#  16  Store_ID_Quantity_mean_lag2             float32
#  17  Store_ID_Quantity_mean_lag3             float32
#  18  Quantity_lag3_mean                      float32
#  19  lag_grad_1                              float32
#  20  lag_grad_2                              float32
# dtypes: float32(11), int16(3), int32(1), int8(6)
# memory usage: 7.1 GB

# %%
X_train = downcast1(X_train)
# Out:
# 0.0% compressed

# %%
del df_forecast
gc.collect()
# Out:
# 30

# %% [markdown]
# ### Models

# %% [markdown]
# #### DECISION TREE - REGRESSOR

# %%
#Run the model with parameters defined 
#Get the R2
model_DT = DecisionTreeRegressor(max_depth=3, min_samples_split=0.5)
model_DT.fit(X_train, y_train)
y_pred_DT = model_DT.predict(X_val)
DT_score = model_DT.score(X_val, y_val)
DT_score
# Out:
# 0.8957234869353843

# %%
#Get the adjusted R2
r2 = r2_score(y_val, y_pred_DT)
n = len(y_val)
p = len(X_train.columns)

def adj_r2 (r2,n,p):
    return 1-(1-r2)*(n-1)/(n-p-1)

adj_r2(r2,n,p)
# Out:
# 0.8957229411019504

# %%
#Get MSE
mean_squared_error(y_val, y_pred_DT, squared = True)
# Out:
# 1.2680223040678613

# %% [markdown]
# #### LIGHT GBM

# %% [markdown]
# #### Light GBM is a gradient boosting that uses tree based learning algorithm. This algorithm is very good to work with very big dataset (our case). LGBM has a high speed and it takes lower memory to run.  In LGBM the tree grows vertically while the other algorithms the tree grows horizontally.

# %%
#Create a function to apply the algorithm LIGHT GBM
def build_lgb_model(params, X_train, X_val, y_train, y_val, cat_features):
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_val = lgb.Dataset(X_val, y_val)
    model = lgb.train(params=params, train_set=lgb_train, valid_sets=(lgb_train, lgb_val), verbose_eval=50,
                     categorical_feature=cat_features)
    return model

# %%
#Define the parameters of algorith
params = {
    'objective': 'rmse',
    'metric': 'rmse',
    'num_leaves': 500,
    'min_data_in_leaf':100,
    'feature_fraction':0.7,
    'learning_rate': 0.01,
    'early_stopping_rounds':10,
    'seed': 1
}

# %%
#designating the categorical features which should be focused on
cat_features = ['Year_Week','Store_ID', 'Product_ID']

# %%
#Run the model with parameters defined 
lgb_model = build_lgb_model(params, X_train, X_val, y_train, y_val, cat_features)
# Out:
# [LightGBM] [Warning] Met categorical feature which contains sparse values. Consider renumbering to consecutive integers started from zero
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 9.534200 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5290
# [LightGBM] [Info] Number of data points in the train set: 111647593, number of used features: 21
# [LightGBM] [Info] Start training from score 1.335993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	training's rmse: 2.31338	valid_1's rmse: 2.17542
# [100]	training's rmse: 1.4578	valid_1's rmse: 1.37191
# Did not meet early stopping. Best iteration is:
# [100]	training's rmse: 1.4578	valid_1's rmse: 1.37191

# %%
#Get the R2
y_pred_lgb = lgb_model.predict(X_val)
r2_lgb = r2_score(y_val, y_pred_lgb)
r2_lgb
# Out:
# 0.8452219965521868

# %%
#Get the adjusted R2
adj_r2(r2_lgb,n,p)
# Out:
# 0.8452211863696573

# %%
#Get MSE
mean_squared_error(y_val, y_pred_lgb, squared = True)
# Out:
# 1.8821300672885404

# %% [markdown]
# #### STORE RESULTS

# %%
X_train_new = X_train.copy()
X_train_new
# Out:
#            Year_Week  Store_ID  Product_ID  Product_ID_Quantity_mean  \
# 0             201728         1        1000                  1.828851
# 1             201728         1        1001                  0.056235
# 2             201728         1        1002                  1.303178
# 3             201728         1        1003                  2.026895
# 4             201728         1        1004                  2.009780
# ...              ...       ...         ...                       ...
# 115659469     201727       363         993                 17.122250
# 115659470     201727       363         994                  1.100245
# 115659471     201727       363         995                  2.586797
# 115659472     201727       363         997                  0.716381
# 115659473     201727       363         998                  0.816626
#
#            Product_ID_Store_ID_Quantity_mean  Store_ID_Quantity_mean  \
# 0                                          2                2.163561
# 1                                          0                2.163561
# 2                                          4                2.163561
# 3                                          0                2.163561
# 4                                          0                2.163561
# ...                                      ...                     ...
# 115659469                                  6                0.802512
# 115659470                                  0                0.802512
# 115659471                                  4                0.802512
# 115659472                                  0                0.802512
# 115659473                                  0                0.802512
#
#            Quantity_lag1  Quantity_lag2  Quantity_lag3  \
# 0                      0              0              0
# 1                      0              0              0
# 2                      2              5              4
# 3                      0              0              0
# 4                      0              2              2
# ...                  ...            ...            ...
# 115659469              6              9             14
# 115659470              1              0              1
# 115659471              2              0              2
# 115659472              0              0              0
# 115659473              0              0              0
#
#            Product_ID_Quantity_mean_lag1  ...  Product_ID_Quantity_mean_lag3  \
# 0                               1.672372  ...                       1.687042
# 1                               0.046455  ...                       0.034230
# 2                               1.124694  ...                       1.293398
# 3                               1.929095  ...                       1.762836
# 4                               1.826406  ...                       1.684597
# ...                                  ...  ...                            ...
# 115659469                      17.691931  ...                      20.000000
# 115659470                       1.063570  ...                       1.298288
# 115659471                       2.388753  ...                       3.420538
# 115659472                       0.691932  ...                       0.655257
# 115659473                       0.694377  ...                       0.880196
#
#            Product_ID_Store_ID_Quantity_mean_lag1  \
# 0                                               0
# 1                                               0
# 2                                               2
# 3                                               0
# 4                                               0
# ...                                           ...
# 115659469                                       6
# 115659470                                       1
# 115659471                                       2
# 115659472                                       0
# 115659473                                       0
#
#            Product_ID_Store_ID_Quantity_mean_lag2  \
# 0                                               0
# 1                                               0
# 2                                               5
# 3                                               0
# 4                                               2
# ...                                           ...
# 115659469                                       9
# 115659470                                       0
# 115659471                                       0
# 115659472                                       0
# 115659473                                       0
#
#            Product_ID_Store_ID_Quantity_mean_lag3  \
# 0                                               0
# 1                                               0
# 2                                               4
# 3                                               0
# 4                                               2
# ...                                           ...
# 115659469                                      14
# 115659470                                       1
# 115659471                                       2
# 115659472                                       0
# 115659473                                       0
#
#            Store_ID_Quantity_mean_lag1  Store_ID_Quantity_mean_lag2  \
# 0                             1.985345                     1.992302
# 1                             1.985345                     1.992302
# 2                             1.985345                     1.992302
# 3                             1.985345                     1.992302
# 4                             1.985345                     1.992302
# ...                                ...                          ...
# 115659469                     0.945927                     0.811174
# 115659470                     0.945927                     0.811174
# 115659471                     0.945927                     0.811174
# 115659472                     0.945927                     0.811174
# 115659473                     0.945927                     0.811174
#
#            Store_ID_Quantity_mean_lag3  Quantity_lag3_mean  lag_grad_1  \
# 0                             1.791754            0.000000    0.000000
# 1                             1.791754            0.000000    0.000000
# 2                             1.791754            3.666667    0.400000
# 3                             1.791754            0.000000    0.000000
# 4                             1.791754            1.333333    0.000000
# ...                                ...                 ...         ...
# 115659469                     0.800000            9.666667    0.666667
# 115659470                     0.800000            0.666667    0.000000
# 115659471                     0.800000            1.333333    0.000000
# 115659472                     0.800000            0.000000    0.000000
# 115659473                     0.800000            0.000000    0.000000
#
#            lag_grad_2
# 0            0.000000
# 1            0.000000
# 2            1.250000
# 3            0.000000
# 4            1.000000
# ...               ...
# 115659469    0.642857
# 115659470    0.000000
# 115659471    0.000000
# 115659472    0.000000
# 115659473    0.000000
#
# [111647593 rows x 21 columns]

# %%
X_val_new = X_val.copy()
X_val_new
# Out:
#            Year_Week  Store_ID  Product_ID  Product_ID_Quantity_mean  \
# 14602527      201937        17           1                  0.007335
# 14602528      201937        17        1000                  1.396088
# 14602529      201937        17        1001                  0.024450
# 14602530      201937        17        1002                  0.838631
# 14602531      201937        17        1003                  2.053790
# ...              ...       ...         ...                       ...
# 105285593     201936       171         993                 18.413202
# 105285594     201936       171         994                  0.481663
# 105285595     201936       171         995                  2.603912
# 105285596     201936       171         997                  0.308068
# 105285597     201936       171         998                  0.034230
#
#            Product_ID_Store_ID_Quantity_mean  Store_ID_Quantity_mean  \
# 14602527                                   2                2.530872
# 14602528                                   4                2.530872
# 14602529                                   0                2.530872
# 14602530                                   1                2.530872
# 14602531                                   0                2.530872
# ...                                      ...                     ...
# 105285593                                 14                0.773839
# 105285594                                  0                0.773839
# 105285595                                  0                0.773839
# 105285596                                  0                0.773839
# 105285597                                  0                0.773839
#
#            Quantity_lag1  Quantity_lag2  Quantity_lag3  \
# 14602527               0              4              0
# 14602528               3              2              4
# 14602529               0              0              0
# 14602530               1              2              4
# 14602531               0              0              0
# ...                  ...            ...            ...
# 105285593             20             19             20
# 105285594              0              0              0
# 105285595              2              0              0
# 105285596              0              0              0
# 105285597              0              0              0
#
#            Product_ID_Quantity_mean_lag1  ...  Product_ID_Quantity_mean_lag3  \
# 14602527                        0.000000  ...                       0.009780
# 14602528                        1.330073  ...                       1.332518
# 14602529                        0.026895  ...                       0.026895
# 14602530                        0.833741  ...                       1.046455
# 14602531                        1.948655  ...                       2.188264
# ...                                  ...  ...                            ...
# 105285593                      18.608803  ...                      16.863081
# 105285594                       0.525672  ...                       0.601467
# 105285595                       2.569682  ...                       2.246944
# 105285596                       0.442543  ...                       0.432763
# 105285597                       0.029340  ...                       0.090465
#
#            Product_ID_Store_ID_Quantity_mean_lag1  \
# 14602527                                        0
# 14602528                                        3
# 14602529                                        0
# 14602530                                        1
# 14602531                                        0
# ...                                           ...
# 105285593                                      20
# 105285594                                       0
# 105285595                                       2
# 105285596                                       0
# 105285597                                       0
#
#            Product_ID_Store_ID_Quantity_mean_lag2  \
# 14602527                                        4
# 14602528                                        2
# 14602529                                        0
# 14602530                                        2
# 14602531                                        0
# ...                                           ...
# 105285593                                      19
# 105285594                                       0
# 105285595                                       0
# 105285596                                       0
# 105285597                                       0
#
#            Product_ID_Store_ID_Quantity_mean_lag3  \
# 14602527                                        0
# 14602528                                        4
# 14602529                                        0
# 14602530                                        4
# 14602531                                        0
# ...                                           ...
# 105285593                                      20
# 105285594                                       0
# 105285595                                       0
# 105285596                                       0
# 105285597                                       0
#
#            Store_ID_Quantity_mean_lag1  Store_ID_Quantity_mean_lag2  \
# 14602527                      0.000000                     2.579497
# 14602528                      2.472494                     2.579497
# 14602529                      2.472494                     2.579497
# 14602530                      2.472494                     2.579497
# 14602531                      2.472494                     2.579497
# ...                                ...                          ...
# 105285593                     0.870610                     0.868227
# 105285594                     0.870610                     0.868227
# 105285595                     0.870610                     0.868227
# 105285596                     0.870610                     0.868227
# 105285597                     0.870610                     0.868227
#
#            Store_ID_Quantity_mean_lag3  Quantity_lag3_mean  lag_grad_1  \
# 14602527                      2.560144            1.333333    0.000000
# 14602528                      2.560144            3.000000    1.500000
# 14602529                      2.560144            0.000000    0.000000
# 14602530                      2.560144            2.333333    0.500000
# 14602531                      2.560144            0.000000    0.000000
# ...                                ...                 ...         ...
# 105285593                     0.778788           20.000000    1.052632
# 105285594                     0.778788            0.000000    0.000000
# 105285595                     0.778788            0.666667    0.000000
# 105285596                     0.778788            0.000000    0.000000
# 105285597                     0.778788            0.000000    0.000000
#
#            lag_grad_2
# 14602527         0.00
# 14602528         0.50
# 14602529         0.00
# 14602530         0.50
# 14602531         0.00
# ...               ...
# 105285593        0.95
# 105285594        0.00
# 105285595        0.00
# 105285596        0.00
# 105285597        0.00
#
# [4011881 rows x 21 columns]

# %%
X_train_new = downcast1(X_train_new)
# Out:
# 0.0% compressed

# %%
#Create the columns to store the results LGBM 
X_train_new['lgb_pred'] = lgb_model.predict(X_train).clip(0,20)
X_train_new['target'] = y_train
X_train_new['sq_err_lgb'] = (X_train_new['lgb_pred']-X_train_new['target'])**2

# %%
#Create the columns to store the results LGBM 
X_val_new['lgb_pred'] = lgb_model.predict(X_val).clip(0,20)
X_val_new['target'] = y_val
X_val_new['sq_err_lgb'] = (X_val_new['lgb_pred']-X_val_new['target'])**2

# %%
#Create the columns to store the results DT
X_train_new['DT_pred'] = model_DT.predict(X_train).clip(0,20)
X_train_new['sq_err_DT'] = (X_train_new['DT_pred']-X_train_new['target'])**2

# %%
#Create the columns to store the results DT
X_val_new['DT_pred'] = model_DT.predict(X_val).clip(0,20)
X_val_new['sq_err_DT'] = (X_val_new['DT_pred']-X_val_new['target'])**2

# %% [markdown]
# #### APPLY ON TEST SET

# %%
#import dataset in csv
test_original = pd.read_csv('teste.csv')

# %%
#TEST SET ORIGINAL
test_original.head()
# Out:
#    Year_Week  Store_ID  Product_ID  Quantity
# 0     201938        17           1       1.0
# 1     201938        17        1000       3.0
# 2     201938        17        1001       0.0
# 3     201938        17        1002       5.0
# 4     201938        17        1003       1.0

# %%
#TEST SET MODIFIED (WITHZERO QUANTITIES AND PREPROCESSED)
X_test = test.drop('Quantity',axis = 1 )
y_test = test['Quantity']

# %%
#DEFINE FEATURES TO MERGE TEST DATASETS
index_feats = ["Year_Week", "Store_ID", "Product_ID"]

# %%
#MERGE DATASETS
X_test_new =pd.merge(X_test, test_original, on=index_feats, how="left")
X_test_new
# Out:
#          Year_Week  Store_ID  Product_ID  Product_ID_Quantity_mean  \
# 0           201938        17           1                       0.0
# 1           201938        17        1000                       0.0
# 2           201938        17        1001                       0.0
# 3           201938        17        1002                       0.0
# 4           201938        17        1003                       0.0
# ...            ...       ...         ...                       ...
# 4702268     201940       221         993                       0.0
# 4702269     201940       221         994                       0.0
# 4702270     201940       221         995                       0.0
# 4702271     201940       221         997                       0.0
# 4702272     201940       221         998                       0.0
#
#          Product_ID_Store_ID_Quantity_mean  Store_ID_Quantity_mean  \
# 0                                        0                     0.0
# 1                                        0                     0.0
# 2                                        0                     0.0
# 3                                        0                     0.0
# 4                                        0                     0.0
# ...                                    ...                     ...
# 4702268                                  0                     0.0
# 4702269                                  0                     0.0
# 4702270                                  0                     0.0
# 4702271                                  0                     0.0
# 4702272                                  0                     0.0
#
#          Quantity_lag1  Quantity_lag2  Quantity_lag3  \
# 0                    2              1              6
# 1                    4              4             12
# 2                    0              1              0
# 3                    1              2              3
# 4                    0              0              1
# ...                ...            ...            ...
# 4702268              0              5              3
# 4702269              0              0              0
# 4702270              0              0              0
# 4702271              0              0              0
# 4702272              0              0              0
#
#          Product_ID_Quantity_mean_lag1  ...  \
# 0                             0.007335  ...
# 1                             1.396088  ...
# 2                             0.024450  ...
# 3                             0.838631  ...
# 4                             2.053790  ...
# ...                                ...  ...
# 4702268                       0.000000  ...
# 4702269                       0.000000  ...
# 4702270                       0.000000  ...
# 4702271                       0.000000  ...
# 4702272                       0.000000  ...
#
#          Product_ID_Store_ID_Quantity_mean_lag1  \
# 0                                             2
# 1                                             4
# 2                                             0
# 3                                             1
# 4                                             0
# ...                                         ...
# 4702268                                       0
# 4702269                                       0
# 4702270                                       0
# 4702271                                       0
# 4702272                                       0
#
#          Product_ID_Store_ID_Quantity_mean_lag2  \
# 0                                             1
# 1                                             4
# 2                                             1
# 3                                             2
# 4                                             0
# ...                                         ...
# 4702268                                       5
# 4702269                                       0
# 4702270                                       0
# 4702271                                       0
# 4702272                                       0
#
#          Product_ID_Store_ID_Quantity_mean_lag3  Store_ID_Quantity_mean_lag1  \
# 0                                             6                     2.530872
# 1                                            12                     2.530872
# 2                                             0                     2.530872
# 3                                             3                     2.530872
# 4                                             1                     2.530872
# ...                                         ...                          ...
# 4702268                                       3                     0.000000
# 4702269                                       0                     0.000000
# 4702270                                       0                     0.000000
# 4702271                                       0                     0.000000
# 4702272                                       0                     0.000000
#
#          Store_ID_Quantity_mean_lag2  Store_ID_Quantity_mean_lag3  \
# 0                           2.728897                     2.852888
# 1                           2.728897                     2.852888
# 2                           2.728897                     2.852888
# 3                           2.728897                     2.852888
# 4                           2.728897                     2.852888
# ...                              ...                          ...
# 4702268                     0.435835                     0.426642
# 4702269                     0.435835                     0.426642
# 4702270                     0.435835                     0.426642
# 4702271                     0.435835                     0.426642
# 4702272                     0.435835                     0.426642
#
#          Quantity_lag3_mean  lag_grad_1  lag_grad_2  Quantity
# 0                  3.000000         2.0    0.166667       1.0
# 1                  6.666667         1.0    0.333333       3.0
# 2                  0.333333         0.0    0.000000       0.0
# 3                  2.000000         0.5    0.666667       5.0
# 4                  0.333333         0.0    0.000000       1.0
# ...                     ...         ...         ...       ...
# 4702268            2.666667         0.0    1.666667       5.0
# 4702269            0.000000         0.0    0.000000       0.0
# 4702270            0.000000         0.0    0.000000       0.0
# 4702271            0.000000         0.0    0.000000       0.0
# 4702272            0.000000         0.0    0.000000       0.0
#
# [4702273 rows x 22 columns]

# %%
#STORE RESULTS LGBM
X_test_new['lgb_pred'] = lgb_model.predict(X_test).clip(0,20)
X_test_new['target'] = X_test_new['Quantity']
X_test_new['sq_err_lgb'] = (X_test_new['lgb_pred']-X_test_new['target'])**2

# %%
#STORE RESULTS DT
X_test_new['DT_pred'] = model_DT.predict(X_test).clip(0,20)
X_test_new['sq_err_DT'] = (X_test_new['DT_pred']-X_test_new['target'])**2

# %%
#GET RMSE
mean_squared_error(X_test_new['target'], X_test_new['lgb_pred'], squared = True)
# Out:
# 36.34839174029889

# %%
#GET MSE
mean_squared_error(X_test_new['target'], X_test_new['DT_pred'], squared = True)
# Out:
# 38.7793630867455

# %%
#CREATE A COLUMN TO IDENTIFY WITCH PART OF DATASET 
X_train_new["dataset"] = 'Train'
X_val_new["dataset"] = 'Validation'
X_test_new["dataset"] = 'Test'

# %%
#Create a function to calculate WAPE
def wmape_gr(df_in, st_actual, st_forecast):
    # we take two series and calculate an output a wmape from it

    # make a series called mape
    se_mape = abs(df_in[st_actual] - df_in[st_forecast]) / df_in[st_actual]

    # get a float of the sum of the actual
    ft_actual_sum = df_in[st_actual].sum()

    # get a series of the multiple of the actual & the mape
    se_actual_prod_mape = df_in[st_actual] * se_mape

    # summate the prod of the actual and the mape
    ft_actual_prod_mape_sum = se_actual_prod_mape.sum()

    # float: wmape of forecast
    ft_wmape_forecast = ft_actual_prod_mape_sum / ft_actual_sum

    # return a float
    return ft_wmape_forecast

# %%
#Calculate wape to lbgm
df_gr_train_LGB = X_train_new.groupby(['Store_ID', 'Product_ID','dataset']).apply(wmape_gr,'target','lgb_pred')

# %%
df_gr_train_LGB.head()
# Out:
# Store_ID  Product_ID  dataset
# 1         1           Train           NaN
#           2           Train           NaN
#           3           Train           NaN
#           4           Train      0.252321
#           5           Train      0.273440
# dtype: float64

# %%
#Calculate wape to DT
df_gr_train_DT = X_train_new.groupby(['Store_ID', 'Product_ID','dataset']).apply(wmape_gr,'target','DT_pred')

# %%
#Reset index
df_gr_train_LGB = df_gr_train_LGB.reset_index()
#Rename aggregate collumn
df_gr_train_LGB = df_gr_train_LGB.rename(columns={0:'wape_lgb'})
#Replace nams by 0
df_gr_train_LGB = df_gr_train_LGB.fillna(0)
df_gr_train_LGB
# Out:
#         Store_ID  Product_ID dataset  wape_lgb
# 0              1           1   Train  0.000000
# 1              1           2   Train  0.000000
# 2              1           3   Train  0.000000
# 3              1           4   Train  0.252321
# 4              1           5   Train  0.273440
# ...          ...         ...     ...       ...
# 865848       410        2846   Train  0.330612
# 865849       410        2847   Train  0.342647
# 865850       410        2848   Train  0.000000
# 865851       410        2849   Train  0.005618
# 865852       410        2850   Train  0.000000
#
# [865853 rows x 4 columns]

# %%
#Reset index
df_gr_train_DT = df_gr_train_DT.reset_index()
#Rename aggregate collumn
df_gr_train_DT = df_gr_train_DT.rename(columns={0:'wape_DT'})
#Replace nams by 0
df_gr_train_DT = df_gr_train_DT.fillna(0)
df_gr_train_DT
# Out:
#         Store_ID  Product_ID dataset   wape_DT
# 0              1           1   Train  0.000000
# 1              1           2   Train  0.000000
# 2              1           3   Train  0.000000
# 3              1           4   Train  0.309775
# 4              1           5   Train  0.346096
# ...          ...         ...     ...       ...
# 865848       410        2846   Train  0.283234
# 865849       410        2847   Train  0.234630
# 865850       410        2848   Train  0.000000
# 865851       410        2849   Train  0.380450
# 865852       410        2850   Train  0.000000
#
# [865853 rows x 4 columns]

# %%
#merge wape DT and WAPE LGBM
df_gr_train = pd.merge(df_gr_train_DT, df_gr_train_LGB, on= ['Store_ID', 'Product_ID','dataset'], how="left")

# %%
del df_gr_train_DT
gc.collect()
# Out:
# 60

# %%
del df_gr_train_LGB
gc.collect()
# Out:
# 15

# %%
#Calculate wape to lbgm
df_gr_val_LGB = X_val_new.groupby(['Store_ID', 'Product_ID','dataset']).apply(wmape_gr,'target','lgb_pred')

# %%
#Calculate wape to DT
df_gr_val_DT = X_val_new.groupby(['Store_ID', 'Product_ID','dataset']).apply(wmape_gr,'target','DT_pred')

# %%
df_gr_val_LGB = df_gr_val_LGB.reset_index()
df_gr_val_LGB = df_gr_val_LGB.rename(columns={0:'wape_lgb'})
df_gr_val_LGB = df_gr_val_LGB.fillna(0)
df_gr_val_LGB
# Out:
#         Store_ID  Product_ID     dataset  wape_lgb
# 0              1           1  Validation  0.000000
# 1              1           2  Validation  0.000000
# 2              1           3  Validation  0.000000
# 3              1           4  Validation  0.000000
# 4              1           5  Validation  0.260470
# ...          ...         ...         ...       ...
# 777913       410        2846  Validation  0.351313
# 777914       410        2847  Validation  0.330202
# 777915       410        2848  Validation  0.000000
# 777916       410        2849  Validation  0.000000
# 777917       410        2850  Validation  0.000000
#
# [777918 rows x 4 columns]

# %%
df_gr_val_DT = df_gr_val_DT.reset_index()
df_gr_val_DT = df_gr_val_DT.rename(columns={0:'wape_DT'})
df_gr_val_DT = df_gr_val_DT.fillna(0)
df_gr_val_DT
# Out:
#         Store_ID  Product_ID     dataset   wape_DT
# 0              1           1  Validation  0.000000
# 1              1           2  Validation  0.000000
# 2              1           3  Validation  0.000000
# 3              1           4  Validation  0.000000
# 4              1           5  Validation  0.309775
# ...          ...         ...         ...       ...
# 777913       410        2846  Validation  0.232896
# 777914       410        2847  Validation  0.275363
# 777915       410        2848  Validation  0.000000
# 777916       410        2849  Validation  0.000000
# 777917       410        2850  Validation  0.000000
#
# [777918 rows x 4 columns]

# %%
#Merge results
df_gr_val = pd.merge(df_gr_val_DT, df_gr_val_LGB, on= ['Store_ID', 'Product_ID','dataset'], how="left")

# %%
#Calculate wape to lbgm
df_gr_test_LGB = X_test_new.groupby(['Store_ID', 'Product_ID','dataset']).apply(wmape_gr,'target','lgb_pred')

# %%
#Calculate wape to DT
df_gr_test_DT = X_test_new.groupby(['Store_ID', 'Product_ID','dataset']).apply(wmape_gr,'target','DT_pred')

# %%
df_gr_test_LGB = df_gr_test_LGB.reset_index()
df_gr_test_LGB = df_gr_test_LGB.rename(columns={0:'wape_lgb'})
df_gr_test_LGB = df_gr_test_LGB.fillna(0)
df_gr_test_LGB
# Out:
#         Store_ID  Product_ID dataset  wape_lgb
# 0              1           1    Test  0.000000
# 1              1           2    Test  0.000000
# 2              1           3    Test  0.000000
# 3              1           4    Test  0.000000
# 4              1           5    Test  0.000000
# ...          ...         ...     ...       ...
# 795909       410        2846    Test  0.948917
# 795910       410        2847    Test  0.962015
# 795911       410        2848    Test  0.000000
# 795912       410        2849    Test  0.000000
# 795913       410        2850    Test  0.000000
#
# [795914 rows x 4 columns]

# %%
df_gr_test_DT = df_gr_test_DT.reset_index()
df_gr_test_DT = df_gr_test_DT.rename(columns={0:'wape_DT'})
df_gr_test_DT = df_gr_test_DT.fillna(0)
df_gr_test_DT
# Out:
#         Store_ID  Product_ID dataset  wape_DT
# 0              1           1    Test      0.0
# 1              1           2    Test      0.0
# 2              1           3    Test      0.0
# 3              1           4    Test      0.0
# 4              1           5    Test      0.0
# ...          ...         ...     ...      ...
# 795909       410        2846    Test      1.0
# 795910       410        2847    Test      1.0
# 795911       410        2848    Test      0.0
# 795912       410        2849    Test      0.0
# 795913       410        2850    Test      0.0
#
# [795914 rows x 4 columns]

# %%
#Merge results
df_gr_test = pd.merge(df_gr_test_DT, df_gr_test_LGB, on= ['Store_ID', 'Product_ID','dataset'], how="left")

# %%
#Append all in one dataframe
df_gr_all = df_gr_train.append(df_gr_val)
df_gr_all = df_gr_all.append(df_gr_test)

# %%
data = X_train_new[['Year_Week', 'Store_ID', 'Product_ID', 'lgb_pred', 'target', 'sq_err_lgb','DT_pred','sq_err_DT','dataset']]

# %%
data.head()
# Out:
#    Year_Week  Store_ID  Product_ID  lgb_pred  target  sq_err_lgb   DT_pred  \
# 0     201728         1        1000  1.552632       2    0.200138  1.380450
# 1     201728         1        1001  0.491883       0    0.241948  0.000000
# 2     201728         1        1002  2.893234       4    1.224932  4.474146
# 3     201728         1        1003  0.539540       0    0.291103  0.000000
# 4     201728         1        1004  0.734470       0    0.539447  0.000000
#
#    sq_err_DT dataset
# 0   0.383842   Train
# 1   0.000000   Train
# 2   0.224815   Train
# 3   0.000000   Train
# 4   0.000000   Train

# %%
data_val = X_val_new[['Year_Week', 'Store_ID', 'Product_ID', 'lgb_pred', 'target', 'sq_err_lgb','DT_pred','sq_err_DT','dataset']]

# %%
data_test = X_test_new[['Year_Week', 'Store_ID', 'Product_ID', 'lgb_pred', 'target', 'sq_err_lgb','DT_pred','sq_err_DT','dataset']]

# %%
#Append all in one dataframe
data_all = data.append(data_val)
data_all = data_all.append(data_test)

# %%
data_all.to_csv(os.path.join("df_demand_final.csv"), index=False)

# %%
df_gr_all.to_csv(os.path.join("df_demand_wape.csv"), index=False)
